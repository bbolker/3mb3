# %%
import cobwebs as cw

# %%
def linfun(x,parms=(3,0.9)):
    a, b = parms  ## unpack parameters
    return(a + b*x)

def logistfun(x,parms=(3.5,)):
    r, = parms  ## unpack parameters
    return(r*x*(1-x))

# %%
# %matplotlib inline
cw.cobweb(linfun,x0=1,parms=(3,0.9),nt=100,maxval=100)

# %%
# %matplotlib inline
cw.cobweb(logistfun,x0=0.2,parms=(3,),nt=100,maxval=1.3)
