# %%
import cobwebs as cw
import bifurc as bf
import matplotlib.pyplot as plt
import numpy as np

# %%
def linfun(x,parms=(3,0.9)):
    a, b = parms  ## unpack parameters
    return(a + b*x)

def logistfun(x,parms=(3.5,)):
    r, = parms  ## unpack parameters
    return(r*x*(1-x))

# %%
# %matplotlib inline
cw.cobweb(linfun,x0=5,parms=(3,-0.9),nt=100,maxval=20)

# %%
# %matplotlib inline
cw.cobweb(logistfun,x0=0.72,parms=(3.7,),nt=1000,maxval=1.3)

# %%
pr = np.arange(2.9,3.7,0.005)
b0 = bf.bifurc(logistfun, parm_range=pr, baseparms=(2,),
                parm_ind=0)

# %%
# %matplotlib inline
plt.plot(pr,b0,'ro',c='black',markersize=2);
